# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
titanic_df = pd.read_csv(url)

# %%
titanic_df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 883          884         0       2
# 620          621         0       3
# 272          273         1       2
# 889          890         1       1
# 37            38         0       3
# 339          340         0       1
# 649          650         1       3
# 599          600         1       1
# 615          616         1       2
# 635          636         1       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 620                           Yasbeck, Mr. Antoni    male  27.0      1      0
# 272     Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.0      0      1
# 889                         Behr, Mr. Karl Howell    male  26.0      0      0
# 37                       Cann, Mr. Ernest Charles    male  21.0      0      0
# 339                  Blackwell, Mr. Stephen Weart    male  45.0      0      0
# ...

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# cabin ==drop
# age=simple imputer
# sex=ordinal encoding
# embarked=OHE
# pclass=ohe
# Then create new dataset from this

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# %%
from sklearn.model_selection import train_test_split

# Separate features and target variable
X = df.drop(columns=['Cabin', 'PassengerId'])
y = df['Survived']  # Replace 'target_column' with the name of your target variable

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# Adding simple imputer to age

# %%
si=SimpleImputer()
xtrainaage=si.fit_transform(x_train[['Age']])

xtestage=si.fit_transform(x_test[['Age']])

xtestage.shape
# Out:
# (357, 1)

# %%
# Out:
# array([[30.31620209],
#        [31.        ],
#        [20.        ],
#        [ 6.        ],
#        [14.        ],
#        [26.        ],
#        [30.31620209],
#        [16.        ],
#        [16.        ],
#        [19.        ],
#        [37.        ],
#        [44.        ],
#        [30.31620209],
#        [30.        ],
#        [36.        ],
#        [16.        ],
#        [42.        ],
#        [30.31620209],
#        [27.        ],
#        [47.        ],
#        [24.        ],
#        [34.        ],
#        [19.        ],
#        [20.        ],
#        [30.31620209],
#        [10.        ],
#        [40.        ],
#        [31.        ],
#        [ 4.        ],
#        [31.        ],
#        [19.        ],
#        [22.        ],
#        [30.31620209],
#        [30.31620209],
#        [18.        ],
#        [27.        ],
#        [28.        ],
#        [30.31620209],
#        [30.        ],
#        [30.31620209],
#        [21.        ],
# ...
